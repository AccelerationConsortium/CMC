# %%
from itertools import combinations
import pandas as pd
import CMC_helper_function as cmc

# %%
# Ratios for surfactant1
ratios = [0.05, 0.2, 0.5, 0.8, 0.95]

# Build all valid binary combos (exclude cationic-anionic)
keys = list(cmc.surfactant_library)
all_combos = [
    (s1, s2, r)
    for s1, s2 in combinations(keys, 2)
    if not (
        (cmc.surfactant_library[s1]['Category'] == 'cationic' and cmc.surfactant_library[s2]['Category'] == 'anionic')
        or
        (cmc.surfactant_library[s1]['Category'] == 'anionic' and cmc.surfactant_library[s2]['Category'] == 'cationic')
    )
    for r in ratios
]

# Create DataFrame with every combo
df = pd.DataFrame(all_combos, columns=['surfactant_1', 'surfactant_2', 'surfactant_1_ratio'])
df['surfactant_2_ratio'] = 1 - df['surfactant_1_ratio']

# Round to two decimals
df[['surfactant_1_ratio', 'surfactant_2_ratio']] = df[['surfactant_1_ratio', 'surfactant_2_ratio']].round(2)

df = df.sort_values(['surfactant_1', 'surfactant_2', 'surfactant_1_ratio']).reset_index(drop=True)
df
# Out:
#    surfactant_1 surfactant_2  surfactant_1_ratio  surfactant_2_ratio
# 0          CAPB        CHAPS                0.05                0.95
# 1          CAPB        CHAPS                0.20                0.80
# 2          CAPB        CHAPS                0.50                0.50
# 3          CAPB        CHAPS                0.80                0.20
# 4          CAPB        CHAPS                0.95                0.05
# ..          ...          ...                 ...                 ...
# 90         TTAB        CHAPS                0.05                0.95
# 91         TTAB        CHAPS                0.20                0.80
# 92         TTAB        CHAPS                0.50                0.50
# 93         TTAB        CHAPS                0.80                0.20
# 94         TTAB        CHAPS                0.95                0.05
#
# [95 rows x 4 columns]

# %%
existing_combos = pd.read_csv('processed_data/all_CMC_processed_data.csv')
existing_combos = existing_combos[existing_combos['surfactant_2_ratio']!= 0.0]
print(existing_combos.shape)
existing_combos = existing_combos.sort_values(['surfactant_1', 'surfactant_2', 'surfactant_1_ratio']).reset_index(drop=True)
existing_combos
# Out:
# (32, 7)
#    surfactant_1 assay  surfactant_1_ratio surfactant_2  surfactant_2_ratio  \
# 0          CAPB   NaN                0.05        CHAPS                0.95
# 1          CAPB   NaN                0.20        CHAPS                0.80
# 2          CAPB   NaN                0.50        CHAPS                0.50
# 3          CTAB   NaN                0.20         CAPB                0.80
# 4          CTAB   NaN                0.95         CAPB                0.05
# 5          CTAB   NaN                0.20        CHAPS                0.80
# 6          CTAB   NaN                0.50         DTAB                0.50
# 7          CTAB   NaN                0.80         DTAB                0.20
# 8          CTAB   NaN                0.20         TTAB                0.80
# 9          CTAB   NaN                0.80         TTAB                0.20
# 10         CTAB   NaN                0.95         TTAB                0.05
# 11         DTAB   NaN                0.05         CAPB                0.95
# 12         DTAB   NaN                0.50         CAPB                0.50
# 13         DTAB   NaN                0.05        CHAPS                0.95
# 14         DTAB   NaN                0.50         TTAB                0.50
# 15         DTAB   NaN                0.80         TTAB                0.20
# 16         DTAB   NaN                0.95         TTAB                0.05
# 17         NaDC   NaN                0.80         CAPB                0.20
# 18         NaDC   NaN                0.80        CHAPS                0.20
# 19         NaDC   NaN                0.05          NaC                0.95
# 20         NaDC   NaN                0.20          NaC                0.80
# 21         NaDC   NaN                0.50          NaC                0.50
# 22          SDS   NaN                0.05          NaC                0.95
# 23          SDS   NaN                0.20          NaC                0.80
# 24          SDS   NaN                0.50          NaC                0.50
# 25          SDS   NaN                0.80          NaC                0.20
# 26          SDS   NaN                0.95          NaC                0.05
# 27          SDS   NaN                0.20         NaDC                0.80
# 28          SDS   NaN                0.80         NaDC                0.20
# 29          SDS   NaN                0.95         NaDC                0.05
# 30         TTAB   NaN                0.05        CHAPS                0.95
# 31         TTAB   NaN                0.80        CHAPS                0.20
#
#           CMC        R2
# 0    5.060144  0.962099
# 1    2.690270  0.918776
# 2    0.989354  0.906185
# 3    0.913345  0.806361
# 4    1.096685  0.889786
# 5    0.919692  0.895863
# 6    1.672338  0.880482
# 7    1.302299  0.924454
# 8    2.430551  0.895319
# 9    1.316639  0.909514
# 10   1.196471  0.944424
# 11   1.121501  0.871513
# 12   1.393133  0.833545
# 13   6.050267  0.963292
# 14   5.508156  0.911016
# 15   8.833683  0.936770
# 16  12.271663  0.946385
# 17   3.333169  0.970147
# 18   1.840795  0.954303
# 19  13.038524  0.972457
# 20   8.390794  0.964671
# 21   4.739894  0.962908
# 22  11.215605  0.962448
# 23   7.872056  0.968804
# 24   6.382770  0.945674
# 25   6.960497  0.961063
# 26   7.615063  0.933659
# 27   3.728162  0.947698
# 28   5.704390  0.936634
# 29   8.000601  0.926120
# 30   3.033631  0.914213
# 31   2.197917  0.907709

# %%
# build a set of tuples for fast membership-testing
existing_set = set(
    existing_combos[['surfactant_1','surfactant_2','surfactant_1_ratio']]
    .itertuples(index=False, name=None)
)

# annotate df in one line
df['done'] = [
    (s1, s2, r) in existing_set
    for s1, s2, r in df[['surfactant_1','surfactant_2','surfactant_1_ratio']].itertuples(index=False, name=None)
]

# %%
print(df[df['done'] == True].shape)
print(df[df['done'] == False].shape)
# Out:
# (32, 5)
# (63, 5)

# %%
df[df['done'] == False].to_csv('processed_data/more_pairs.csv')

# %%
df[df['done'] == False].head(60)
# Out:
#    surfactant_1 surfactant_2  surfactant_1_ratio  surfactant_2_ratio   done
# 3          CAPB        CHAPS                0.80                0.20  False
# 4          CAPB        CHAPS                0.95                0.05  False
# 5          CTAB         CAPB                0.05                0.95  False
# 7          CTAB         CAPB                0.50                0.50  False
# 8          CTAB         CAPB                0.80                0.20  False
# 10         CTAB        CHAPS                0.05                0.95  False
# 12         CTAB        CHAPS                0.50                0.50  False
# 13         CTAB        CHAPS                0.80                0.20  False
# 14         CTAB        CHAPS                0.95                0.05  False
# 15         CTAB         DTAB                0.05                0.95  False
# 16         CTAB         DTAB                0.20                0.80  False
# 19         CTAB         DTAB                0.95                0.05  False
# 20         CTAB         TTAB                0.05                0.95  False
# 22         CTAB         TTAB                0.50                0.50  False
# 26         DTAB         CAPB                0.20                0.80  False
# 28         DTAB         CAPB                0.80                0.20  False
# 29         DTAB         CAPB                0.95                0.05  False
# 31         DTAB        CHAPS                0.20                0.80  False
# 32         DTAB        CHAPS                0.50                0.50  False
# 33         DTAB        CHAPS                0.80                0.20  False
# 34         DTAB        CHAPS                0.95                0.05  False
# 35         DTAB         TTAB                0.05                0.95  False
# 36         DTAB         TTAB                0.20                0.80  False
# 40          NaC         CAPB                0.05                0.95  False
# 41          NaC         CAPB                0.20                0.80  False
# 42          NaC         CAPB                0.50                0.50  False
# 43          NaC         CAPB                0.80                0.20  False
# 44          NaC         CAPB                0.95                0.05  False
# 45          NaC        CHAPS                0.05                0.95  False
# 46          NaC        CHAPS                0.20                0.80  False
# 47          NaC        CHAPS                0.50                0.50  False
# 48          NaC        CHAPS                0.80                0.20  False
# 49          NaC        CHAPS                0.95                0.05  False
# 50         NaDC         CAPB                0.05                0.95  False
# 51         NaDC         CAPB                0.20                0.80  False
# 52         NaDC         CAPB                0.50                0.50  False
# 54         NaDC         CAPB                0.95                0.05  False
# 55         NaDC        CHAPS                0.05                0.95  False
# 56         NaDC        CHAPS                0.20                0.80  False
# 57         NaDC        CHAPS                0.50                0.50  False
# 59         NaDC        CHAPS                0.95                0.05  False
# 63         NaDC          NaC                0.80                0.20  False
# 64         NaDC          NaC                0.95                0.05  False
# 65          SDS         CAPB                0.05                0.95  False
# 66          SDS         CAPB                0.20                0.80  False
# 67          SDS         CAPB                0.50                0.50  False
# 68          SDS         CAPB                0.80                0.20  False
# 69          SDS         CAPB                0.95                0.05  False
# 70          SDS        CHAPS                0.05                0.95  False
# 71          SDS        CHAPS                0.20                0.80  False
# 72          SDS        CHAPS                0.50                0.50  False
# 73          SDS        CHAPS                0.80                0.20  False
# 74          SDS        CHAPS                0.95                0.05  False
# 80          SDS         NaDC                0.05                0.95  False
# 82          SDS         NaDC                0.50                0.50  False
# 85         TTAB         CAPB                0.05                0.95  False
# 86         TTAB         CAPB                0.20                0.80  False
# 87         TTAB         CAPB                0.50                0.50  False
# 88         TTAB         CAPB                0.80                0.20  False
# 89         TTAB         CAPB                0.95                0.05  False
